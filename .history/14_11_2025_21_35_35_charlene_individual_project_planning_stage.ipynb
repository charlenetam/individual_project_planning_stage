# %% [markdown]
# # Project Planning Stage (Individual)

# %%
# please load the below before proceeding
library(tidyverse)
library(tidymodels)
library(repr)
library(cowplot)
options(repr.matrix.max.rows = 6)

# %% [markdown]
# ## (1) Data Description

# %%
# loading in the given data for the project
# this is the only loaded file as it is the only one relevant to my research question
players <- read_csv("data/players.csv")

# %%
summary(players)

# %% [markdown]
# According to the summary above, the data set `players.csv`contains **196 observations**, where each observation represents a unique player, and **7 variables**.
#
# Among the 7 variables, 4 of which fall into the `character` type, including `experience`(the players' self-reported experience of the game), `hashedEmail`(a unique identifier for each player), `name`(the players' in-game name), and `gender`(the players' self-reported gender). 2

# %%
mean_table <- players |>
    summarize(
        "Played Hours" = round(mean(played_hours, na.rm = TRUE), 2),
        "Age" = round(mean(Age, na.rm = TRUE), 2)
    ) |>
    pivot_longer(
        cols = everything(),
        names_to = "Variable",
        values_to = "Mean"
    )
mean_table

# %% [markdown]
# # (2) Questions

# %% [markdown]
# # (3) Exploratory Data Analysis and Visualization

# %% [markdown]
# # (4) Methods and Plan

# %% [markdown]
# # (5) GitHub Repository

# %% [markdown]
# [GitHub Link](https://github.com/charlenetam/individual_project_planning_stage)
