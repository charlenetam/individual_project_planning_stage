# %% [markdown]
# # Project Planning Stage (Individual)

# %%
#please load the below before proceeding
library(tidyverse)
library(tidymodels)
library(repr)
library(cowplot)
library(skimr)
options(repr.matrix.max.rows = 6)

# %% [markdown]
# ## (1) Data Description

# %%
#loading in the given data for the project
players <- read_csv("data/players.csv")
sessions <- read_csv("data/sessions.csv")

# %%
average_chart <- players |>
    group_by(experience) |>
    summarize(
        avg_played_hours = round(mean(played_hours, na.rm = TRUE), digits = 2),
        avg_age = round(mean(Age, na.rm = TRUE), digits = 2)
    )
average_chart

# %% [markdown]
# # (2) Questions

# %% [markdown]
# # (3) Exploratory Data Analysis and Visualization

# %% [markdown]
# # (4) Methods and Plan

# %% [markdown]
# # (5) GitHub Repository

# %% [markdown]
# GitHub Link:
# https://github.com/charlenetam/individual_project_planning_stage
